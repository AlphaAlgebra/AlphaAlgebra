# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/Screenshot 2026-03-26 9.30.55 PM.png
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/Screenshot 2026-03-25 4.02.33 PM.png
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/Screenshot 2026-03-26 12.39.31 PM.png
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/Gemini solves the matrix.png
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/Screenshot 2026-03-26 9.19.56 PM.png
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/CONTRIBUTING.md
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/.pre-commit-config.yaml
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/quickstart.py
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/LICENSE
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/.gitignore
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/main.py
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/pyproject.toml
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/README.md
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/uv.lock
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/.env.example
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/.python-version
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/test_environment_files/game1/metadata.json
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/test_environment_files/game1/bt11.py
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/test_environment_files/game2/subdir/bt33.py
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/test_environment_files/game2/subdir/metadata.json
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/arc_agi/local_wrapper.py
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/arc_agi/server.py
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/arc_agi/scorecard.py
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/arc_agi/remote_wrapper.py
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/arc_agi/base.py
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/arc_agi/rendering.py
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/arc_agi/api.py
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/arc_agi/models.py
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/arc_agi/__init__.py
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/arc_agi/wrapper.py
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/tests/test_models.py
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/tests/test_local_wrapper.py
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/tests/test_scorecard.py
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/tests/test_listen_and_serve.py
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/tests/__init__.py
# /kaggle/input/datasets/jasminekeebler/acr-agi-solver/ARC-AGI-main (1)/ARC-AGI-main/tests/test_base.py
